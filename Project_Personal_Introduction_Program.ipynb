# %% [markdown]
# <a href="https://colab.research.google.com/github/Afroz13/Data-Science-Projects/blob/main/Project_Personal_Introduction_Program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("  Hellow world ! \n  My name Is MD AFROZ ANSARI \n \t Welcome to new world of coding in Data science ........")
# Out:
#   Hellow world !
#   My name Is MD AFROZ ANSARI
#  	 Welcome to new world of coding in Data science ........

# %%
# " AIM : Create a program that asks for user's name, age, and hobby, then displays a friendly welcome message with their information "

# %%
name = input("What is your Name? \t")
# Out:
# What is your Name? 	MD Afroz Ansari

# %%
age = input("What is your age ? \t")
# Out:
# What is your age ? 	24

# %%
Hobby = input("What are your Hobbies ? \t ")
# Out:
# What are your Hobbies ? 	  Playing, Travelling, Swimming

# %%
# The Welcome Message

# %%
print(f" Welcome {name} ! ")
# Out:
#  Welcome MD Afroz Ansari !

# %%
print(f"You are {age} years old and love to {Hobby}")
# Out:
# You are 24 years old and love to  Playing, Travelling, Swimming
